# %% [markdown]
# Classes allow you to define blueprints for creating objects that encapsulate data and behavior. Classes have two main types of members:
#
# - Attributes: These are like variables that belong to the class. They represent the data or state of an object.
# - Methods: These are functions that belong to the class.
#
# They define the behaviours or actions an object can
# perform.

# %% [markdown]
# ### Structure of a Class
#
# A class in Python is defined using the `class` keyword, followed by the class name. Here's the basic structure of a class:
#
# ```python
# class ClassName:
#     def __init__(self, parameter1, parameter2):
#         self.attribute1 = parameter1
#         self.attribute2 = parameter2
#
#     def method1(self):
#         # Method implementation
#
#     def method2(self):
#         # Method implementation
# ```

# %% [markdown]
# Components of a class:
#
# - `__init__` method (**constructor**): This is a special method that is called when an instance of the class is created. It is used to initialize the attributes of the class. The `self` parameter refers to the instance being created, and it is used to access the attributes and methods of the class within the class definition.
#
# - **Attributes**: Attributes are variables that hold data specific to each instance of the class. They are defined inside the `__init__` method using the `self` keyword followed by the attribute name (e.g., `self.attribute1 = parameter1`).
#
# - **Methods**: Methods are functions defined inside a class. They define the behavior and actions that instances of the class can perform. Methods also take the `self` parameter as the first argument, which allows them to access the attributes and other methods of the class.

# %% [markdown]
# ### Example

# %%
class Dog:
    
    # Class attribute
    species = "Canis familiaris"
    
    # Constructor method
    def __init__(self, name, age):
        
        # Instance attributes
        self.name = name
        self.age = age
        
        # Instance method
    def bark(self):
        return "Woof!"

# %%
my_dog = Dog("Buddy", 11)
other_dog = Dog("Max", 7)

print(my_dog.species)
print(my_dog.name, other_dog.name)
print(my_dog.age, other_dog.age)
print(my_dog.bark(), other_dog.bark())
print(my_dog.species)
# Out:
# Canis familiaris
# Buddy Max
# 11 7
# Woof! Woof!
# Canis familiaris

# %% [markdown]
# `species` is a class attribute. It's shared by all instances of the class.
# - `__init__` is a special method called a constructor. It's used to initialize new objects.
# - `self` refers to the instance of the class being created.
# - `name` and `age` are instance attributes. Each object will have its own values for these.
# - `bark` is an instance method. It defines a behaviour for our Dog objects.

# %% [markdown]
# #### To start, there are some conventions and rules about creating classes:
#
# - Always start class names with a capital letter. This is a convention in Python.
# - The ``self`` parameter in methods refers to the instance of the class. Don't forget to include it as the first parameter in your methods!
# - You can create as many objects as you want from a single class.
# - Classes help you organize your code and make it reusable. Think about how you can group related
# data and functions into classes.

# %% [markdown]
# ---
# ## Inheritance
# Inheritance is a fundamental principle in object-oriented programming. It's a mechanism that allows us to create new classes based on existing classes. This
# means we can build on what we already have, saving time and reducing code duplication.
#
# Let's break it down with some key terms:
# - **Superclass**: This is the original class from which
# we're inheriting. You might also hear it called the
# parent class or base class.
# - **Subclass**: This is the new class we create that
# inherits from the superclass. It's sometimes
# referred to as the child class or derived class.

# %% [markdown]
# >The syntax for inheritance is pretty straightforward:
#
# ```python
# class Superclass:
#     # Superclass attributes and methods
# class Subclass(Superclass):
#     # Subclass attributes and methods
# ```

# %% [markdown]
# ### Example

# %%
class Animal:

    def __init__(self, name):
        self.name = name
        
    def speak(self):
        print("The animal makes a sound")
        
class Dog(Animal):
        def speak(self):
            print(f"{self.name} says Woof!")
            
# Creating instances
generic_animal = Animal("Generic")
my_dog = Dog("Buddy")
# Using the objects
generic_animal.speak() # Output: The animal makes a sound
my_dog.speak() # Output: Buddy says Woof!
# Out:
# The animal makes a sound
# Buddy says Woof!

# %% [markdown]
# In this example, `Animal` is our `superclass`, and `Dog` is
# class Flyer: our `subclass`. Notice how `Dog` inherits the name
# attribute from `Animal`, but we've given it a more specific speak method.
